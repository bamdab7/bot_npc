# %% [markdown]
# ## Imaxe do dia NASA 🪐
# * Acceder á API da NASA e descargar a imaxe do día, así como o seu título e descrición.

# %%
#librerias necesarias 
import requests 
import pandas as pd
from IPython import display

#TODO -> en bot, hacer que la imagen se descargue quizas en el dispositivo? ver como mostrarla

# %%
url = "https://api.nasa.gov/planetary/apod"
api_key = "0LriAYOQvavORehcyvdO8QHcVhtEgg0Jr65ECYLe"

# %%
response = requests.get(url, params = {"api_key" : api_key})

response.json()
# Out:
# {'copyright': '\nJAXA, \nTakara Tomy, \nSony Co., \nDoshisha U.\n',
#  'date': '2024-01-30',
# ...

# %%
titulo_image = response.json()["title"]
descripcion = response.json()["explanation"]

image = response.json()["url"]

# %%
print(f"O titulo da imaxe do dia -> {titulo_image}\nDescripcion -> {descripcion}")
# Out:
# O titulo da imaxe do dia -> SLIM Lands on the Moon
# ...

# %%
display.Image(image)
